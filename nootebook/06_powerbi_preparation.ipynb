# %% [markdown]
# # Diabetes Risk & Population Health Analytics
# ## 06 - Power BI Dashboard Preparation
#
# This notebook prepares the final analytics dataset for Power BI dashboard development.
#
# The dataset includes:
# - Clinical indicators
# - Lifestyle risk factors
# - Population health metrics
# - Cluster segmentation labels
#
# The final dataset will be exported for dashboard visualization and executive reporting.

# %%
import pandas as pd

# %% [markdown]
# ## Load Featured Dataset

# %%
df = pd.read_csv(
    "/drive/diabetes-risk-analytics-project/data/featured_diabetes_data.csv"
)

df.head()
# Out:
#    Diabetes_binary  HighBP  HighChol  CholCheck   BMI  Smoker  Stroke  \
# 0                0       1         1          1  40.0       1       0
# 1                0       0         0          0  25.0       1       0
# 2                0       1         1          1  28.0       0       0
# 3                0       1         0          1  27.0       0       0
# 4                0       1         1          1  24.0       0       0
#
#    HeartDiseaseorAttack  PhysActivity  Fruits  ...  NoDocbcCost  GenHlth  \
# 0                     0             0       0  ...            0      5.0
# 1                     0             1       0  ...            1      3.0
# 2                     0             0       1  ...            1      5.0
# 3                     0             1       1  ...            0      2.0
# 4                     0             1       1  ...            0      2.0
#
#    MentHlth  PhysHlth  DiffWalk  Sex   Age  Education  Income  Cluster
# ...

# %% [markdown]
# ## Dataset Overview

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

df.info()
# Out:
# Rows: 229474
# Columns: 23
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229474 entries, 0 to 229473
# Data columns (total 23 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Diabetes_binary       229474 non-null  int64
#  1   HighBP                229474 non-null  int64
#  2   HighChol              229474 non-null  int64
#  3   CholCheck             229474 non-null  int64
#  4   BMI                   229474 non-null  float64
#  5   Smoker                229474 non-null  int64
#  6   Stroke                229474 non-null  int64
#  7   HeartDiseaseorAttack  229474 non-null  int64
#  8   PhysActivity          229474 non-null  int64
#  9   Fruits                229474 non-null  int64
#  10  Veggies               229474 non-null  int64
#  11  HvyAlcoholConsump     229474 non-null  int64
#  12  AnyHealthcare         229474 non-null  int64
#  13  NoDocbcCost           229474 non-null  int64
# ...

# %% [markdown]
# ## Validate Cluster Distribution

# %%
df["Cluster"].value_counts()
# Out:
# Cluster
# 0    91590
# 2    83470
# 1    54414
# Name: count, dtype: int64

# %% [markdown]
# ## Validate Diabetes Distribution

# %%
df["Diabetes_binary"].value_counts()
# Out:
# Diabetes_binary
# 0    194377
# 1     35097
# Name: count, dtype: int64

# %% [markdown]
# ## Export Final Dashboard Dataset

# %%
df.to_csv(
    "/drive/diabetes-risk-analytics-project/data/dashboard_diabetes_data.csv",
    index=False
)

print("Dashboard dataset exported successfully.")
# Out:
# Dashboard dataset exported successfully.

# %% [markdown]
# ## Dashboard Preparation Summary
#
# The final dashboard dataset was successfully prepared and exported.
#
# The exported dataset contains:
#
# - Diabetes status
# - Clinical risk indicators
# - Behavioral health variables
# - Demographic information
# - Cluster segmentation labels
#
# This dataset is ready for Power BI dashboard development and executive reporting.
